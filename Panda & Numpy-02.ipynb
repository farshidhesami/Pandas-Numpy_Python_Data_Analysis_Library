# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
# ### html file  :
#
# https://www.teoalida.com/cardatabase/samples/Car-Models-List-by-Teoalida-SAMPLE.csv
# https://www.teoalida.com/cardatabase/
# https://datahub.io/machine-learning/autos

# %%
pd.read_csv("addresses.csv")
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
pd.read_csv("Vehicle Specifications.csv")
# Out:
#      normalized-losses         make fuel-type aspiration num-of-doors  \
# 0                  NaN  alfa-romero       gas        std          two
# 1                  NaN  alfa-romero       gas        std          two
# 2                  NaN  alfa-romero       gas        std          two
# 3                164.0         audi       gas        std         four
# 4                164.0         audi       gas        std         four
# ..                 ...          ...       ...        ...          ...
# 200               95.0        volvo       gas        std         four
# 201               95.0        volvo       gas      turbo         four
# 202               95.0        volvo       gas        std         four
# 203               95.0        volvo    diesel      turbo         four
# 204               95.0        volvo       gas      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base  length  ...  \
# ...

# %%
import pandas as pd

# !pip install lxml

# %%
data = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
### pandas.DataFrame.dtypes( https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dtypes.html)
### https://pandas.pydata.org/docs/user_guide/basics.html#basics-dtypes

data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
### pandas.DataFrame.describe 
### https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html
### The mean, standard deviation, min and max values
### 
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
### pandas.DataFrame.info 
### (https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
### https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html
### The number of unique values
### The top (most frequent) value
### The frequency of your top value

data[["Name" , "Sex" , "Ticket"]].describe()
# Out:
#                            Name   Sex  Ticket
# count                       891   891     891
# unique                      891     2     681
# top     Braund, Mr. Owen Harris  male  347082
# freq                          1   577       7

# %% [markdown]
# ### Pandas Series is :
#
# - A one-dimensional labeled array capable of holding data of any type (integer, string, float, python objects, etc.).
# - The axis labels are collectively called index. Pandas Series is nothing but a column in an excel sheet.
# - Labels need not be unique but must be a hashable type.
# - The object supports both integer and label-based indexing and provides a host of methods for performing operations involving the index.
#
# https://www.geeksforgeeks.org/python-pandas-series/

# %%
### 
type(data.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Pandas dtype mapping :
# https://pbpython.com/pandas_dtypes.html

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
### Find object(True) 

data.dtypes == "object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
### ### Find object(True) and fillter object 

data.dtypes[data.dtypes == "object" ]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
### Show INDEX :

data.dtypes[data.dtypes == "object" ].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
### Show data in chart :

data[data.dtypes[data.dtypes == "object" ].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
data[data.dtypes[data.dtypes == "object" ].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Question : Try to filter out only a DATASET where " Survived" equals to zero ?????

# %%
data["Survived"]
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
data["Survived"] == 0
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Survived, Length: 891, dtype: bool

# %% [markdown]
# ### Question : Try to filter out only a DATASET where " Survived" equals to zero and  "Male" ?????

# %%
data[(data["Survived"] == 0) & (data["Sex"] == "male") ]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 881          882         0       3              Markun, Mr. Johann  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
### Lets count all data :
data[(data["Survived"] == 0) & (data["Sex"] == "male")].count()
# Out:
# PassengerId    468
# Survived       468
# Pclass         468
# Name           468
# Sex            468
# Age            360
# SibSp          468
# Parch          468
# Ticket         468
# Fare           468
# Cabin           62
# Embarked       468
# dtype: int64

# %%
### male :

len(data[(data["Survived"] == 0) & (data["Sex"] == "male")])
# Out:
# 468

# %%
### female :

len(data[(data["Survived"] == 0) & (data["Sex"] == "female")])
# Out:
# 81

# %%
### Question about number of female and male :

data["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
data["Sex"] == "male"
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Sex, Length: 891, dtype: bool

# %%
## Filttering "male" data :

data[data["Sex"] == "male"]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
len(data[data["Sex"] == "male"])
# Out:
# 577

# %%
## Filttering "female" data :

data["Sex"] == "female"
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: Sex, Length: 891, dtype: bool

# %%
data[data["Sex"] == "female"]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(data["Sex"] == "female")
# Out:
# 891

# %% [markdown]
# ### question: How many male and felale survived ?
#
# - change-----> "Survived" == 0      to "Survived" == 1

# %%
len(data[(data["Survived"] == 1) & (data["Sex"] == "male")])
# Out:
# 109

# %%
len(data[(data["Survived"] == 1) & (data["Sex"] == "female")])
# Out:
# 233

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### question: can you please give me a name of person who has a highest fare ?

# %%
max(data["Fare"])
# Out:
# 512.3292

# %%
data["Fare"] == max(data["Fare"])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
### Max Fare is : 512.3292 3 Persons 1 person is Survived .

data[data["Fare"] == max(data["Fare"])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
### Number of persons :

len(data[data["Fare"] == max(data["Fare"])])
# Out:
# 3

# %%
### Find a name of person :

data[data["Fare"] == max(data["Fare"])]["Name"]
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
data[data["Fare"] == max(data["Fare"])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
##Person Fare 0 and survived

data[data["Fare"] == min(data["Fare"])]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
data[data["Fare"] == max(data["Fare"])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Question :Find person who have receved a Cabin?

# %%
data["Cabin"] != "NaN"
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 886    True
# 887    True
# 888    True
# 889    True
# 890    True
# Name: Cabin, Length: 891, dtype: bool

# %% [markdown]
# ### Check for NaN Value in Pandas DataFrame :
# - NaN, which stands for not-a-number, is a numeric type. This means that NaN can appear in columns of type "int" and "float".
#
# - The ways to check for NaN in Pandas DataFrame are as follows:
#
#     - Check for NaN with isnull().values.any() method
#     - Count the NaN Using isnull().sum() Method
#     - Check for NaN Using isnull().sum().any() Method
#     - Count the NaN Using isnull().sum().sum() Method

# %%
data[data["Cabin"] != "NaN"]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Pandas DataFrame isnull() Method
#
# - The isnull() method returns a DataFrame object where all the values are replaced with a Boolean value True for NULL values,
# - and otherwise False.
# - Pandas isnull() and notnull() methods are used to check and manage NULL values in a data frame.
#
# - NaN value is one of the major problems in Data Analysis. It is very essential to deal with NaN in order to get the desired results.

# %%
data["Cabin"].isnull()
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Cabin, Length: 891, dtype: bool

# %%
### Change to "False" and there is no "NaN" in chart :

data[data["Cabin"].isnull() == False]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
### 204 person who have recived cabin.

len(data[data["Cabin"].isnull() == False])
# Out:
# 204

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Adding new column to existing DataFrame in Pandas

# %%
data["New_col"] = "Farshid"

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
### Add new_Text

data["New_text"] = data["Name"]

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Adding new DataFrame to Sumation "Age" and "Pclass" :

# %%
data["Age_Pclass"] = data["Age"]  +  data["Pclass"]

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  New_col  \
# 0      0         A/5 21171   7.2500   NaN        S  Farshid
# 1      0          PC 17599  71.2833   C85        C  Farshid
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Farshid
# 3      0            113803  53.1000  C123        S  Farshid
# ...

# %% [markdown]
# ### Delete  new DataFrame with "drop()  :
# - axis = 1 -----> Colume
# - axis = 0 -----> Rows

# %%
data.drop("New_col" , axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
### "New_col" is not delete in original file .

data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  New_col  \
# 0      0         A/5 21171   7.2500   NaN        S  Farshid
# 1      0          PC 17599  71.2833   C85        C  Farshid
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Farshid
# 3      0            113803  53.1000  C123        S  Farshid
# ...

# %% [markdown]
# ### Delet rows forever:
#
# ### Drop signature :
# Signature:
# - data.drop(
#     - labels: 'IndexLabel' = None,
#     *,
#     - axis: 'Axis' = 0,
#     - index: 'IndexLabel' = None,
#     - columns: 'IndexLabel' = None,
#     - level: 'Level' = None,
#     - inplace: 'bool' = False,------------>delete
#     - errors: 'IgnoreRaise' = 'raise',

# %%
data.drop("New_col" , axis=1 , inplace=True)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  \
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
#
# ...

# %% [markdown]
# ### Difference between loc() and iloc() in Pandas DataFrame :
#
# - The loc() function is label based data selecting method which means that we have to pass the name of the row or column which we want to select. This method includes the last element of the range passed in it, unlike iloc(). loc() can accept the boolean data unlike iloc().
#
# - از اندیس سطر و ستون برای دسترسی
#
# - The iloc() function is an indexed-based selecting method which means that we have to pass an integer index in the method to select a specific row/column. This method does not include the last element of the range passed in it unlike loc(). iloc() does not accept the boolean data unlike loc().
#
# - متد از لیبل یا برچسب سطر و ستون برای دسترسی به آن استفاده می‌کند

# %% [markdown]
# ### Can you Extract Row number 1 :

# %%
data.iloc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# New_text       Braund, Mr. Owen Harris
# Age_Pclass                        25.0
# Name: 0, dtype: object

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  \
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
#
# ...

# %%
data.loc[20:30]
# Out:
#     PassengerId  Survived  Pclass  \
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
# 27           28         0       1
# 28           29         1       3
# 29           30         0       3
# 30           31         0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# ...

# %% [markdown]
# ### Try to fetch a recode starting from 101 until 106 indexes :

# %%
data.loc[101:106]
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 101          102         0       3  Petroff, Mr. Pastcho ("Pentcho")    male
# 102          103         0       1         White, Mr. Richard Frasar    male
# 103          104         0       3        Johansson, Mr. Gustaf Joel    male
# 104          105         0       3    Gustafsson, Mr. Anders Vilhelm    male
# 105          106         0       3             Mionoff, Mr. Stoytcho    male
# 106          107         1       3  Salkjelsvik, Miss. Anna Kristine  female
#
#       Age  SibSp  Parch   Ticket     Fare Cabin Embarked  \
# 101   NaN      0      0   349215   7.8958   NaN        S
# 102  21.0      0      1    35281  77.2875   D26        S
# 103  33.0      0      0     7540   8.6542   NaN        S
# 104  37.0      2      0  3101276   7.9250   NaN        S
# 105  28.0      0      0   349207   7.8958   NaN        S
# 106  21.0      0      0   343120   7.6500   NaN        S
#
# ...

# %% [markdown]
# ### Try to fetch a recode starting from 101 until 106 indexes with "Survived" and "New_text" :

# %%
data.loc[101:106 , ["New_text"]]
# Out:
#                              New_text
# 101  Petroff, Mr. Pastcho ("Pentcho")
# 102         White, Mr. Richard Frasar
# 103        Johansson, Mr. Gustaf Joel
# 104    Gustafsson, Mr. Anders Vilhelm
# 105             Mionoff, Mr. Stoytcho
# 106  Salkjelsvik, Miss. Anna Kristine

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
### add [3,4] insted of [3:4]

data.loc[[3,4] ,["Fare" , "Cabin" ,"Embarked"]]
# Out:
#     Fare Cabin Embarked
# 3  53.10  C123        S
# 4   8.05   NaN        S

# %%
data.loc[102:103 ,["Survived" , "Pclass" ]]
# Out:
#      Survived  Pclass
# 102         0       1
# 103         0       3

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.iloc[886]
# Out:
# PassengerId                      887
# Survived                           0
# Pclass                             2
# Name           Montvila, Rev. Juozas
# Sex                             male
# Age                             27.0
# SibSp                              0
# Parch                              0
# Ticket                        211536
# Fare                            13.0
# Cabin                            NaN
# Embarked                           S
# New_text       Montvila, Rev. Juozas
# Age_Pclass                      29.0
# Name: 886, dtype: object

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## same Result and compare "loc" and "iloc" :

# %%
data.iloc[888:890 , [3,4,5]]
# Out:
#                                          Name     Sex   Age
# 888  Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                     Behr, Mr. Karl Howell    male  26.0

# %%
data.loc[888:889 , ["Name" , "Sex" , "Age"]]
# Out:
#                                          Name     Sex   Age
# 888  Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                     Behr, Mr. Karl Howell    male  26.0

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## fetch All Row  for reach "PassengerId" , "Pclass"

# %%
## With  iloc
 
data.loc[ : , ["PassengerId" ,  "Pclass"]]
# Out:
#      PassengerId  Pclass
# 0              1       3
# 1              2       1
# 2              3       3
# 3              4       1
# 4              5       3
# ..           ...     ...
# 886          887       2
# 887          888       1
# 888          889       3
# 889          890       1
# 890          891       3
#
# [891 rows x 2 columns]

# %%
## With  loc

data.iloc[ : , [0,2]]
# Out:
#      PassengerId  Pclass
# 0              1       3
# 1              2       1
# 2              3       3
# 3              4       1
# 4              5       3
# ..           ...     ...
# 886          887       2
# 887          888       1
# 888          889       3
# 889          890       1
# 890          891       3
#
# [891 rows x 2 columns]

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Question :
#
# Give a Row 886 and 888 and colume "PassengerId" , "Survived" , "Pclass" ...........
#
# #Note : we used [886,888] vs [886:888

# %%
data.loc[[886,888] , ["PassengerId" , "Survived" , "Pclass"]]
# Out:
#      PassengerId  Survived  Pclass
# 886          887         0       2
# 888          889         0       3

# %%
data.loc[886:888 , ["PassengerId" , "Survived" , "Pclass"]]
# Out:
#      PassengerId  Survived  Pclass
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3

# %% [markdown]
# ## Question : Age > 35

# %%
data[data["Age"] > 35]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Question : Age > 35  and Pclass == 1  ???????????

# %% [markdown]
# ## Create Subset :

# %%
data1 = data.iloc[1:6 , [2,3,4,5,9,10]]

# %%
data1
# Out:
#    Pclass                                               Name     Sex   Age  \
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                           Allen, Mr. William Henry    male  35.0
# 5       3                                   Moran, Mr. James    male   NaN
#
#       Fare Cabin
# 1  71.2833   C85
# 2   7.9250   NaN
# 3  53.1000  C123
# 4   8.0500   NaN
# 5   8.4583   NaN

# %% [markdown]
# ## Question : pandas.DataFrame.set_index and used inplace = True

# %% [markdown]
# ### pandas.DataFrame.set_index :
#
# - Pandas set_index() is a method to set a List, Series or Data frame as index of a Data Frame. Index column can be set while making a data frame too. But sometimes a data frame is made out of two or more data frames and hence later index can be changed using this method.
#
# ### Parameters:
# - keys: Column name or list of column name.
# - drop: Boolean value which drops the column used for index if True.
# - append: Appends the column to existing index column if True.
# - inplace: Makes the changes in the dataframe if True.
# - verify_integrity: Checks the new index column for duplicates if True.
#
# https://www.geeksforgeeks.org/python-pandas-dataframe-set_index/
#
# - Signature:
# - data.set_index(
#     - keys,
#       *,
#       - drop: 'bool' = True,
#       - append: 'bool' = False,
#       - inplace: 'bool' = False, ----------> cchange
#       - verify_integrity: 'bool' = False,

# %%
data1.set_index("Name",inplace = True)

# %%
data1
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
# Moran, Mr. James                                         3    male   NaN
#
#                                                        Fare Cabin
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Heikkinen, Miss. Laina                               7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123
# Allen, Mr. William Henry                             8.0500   NaN
# Moran, Mr. James                                     8.4583   NaN

# %% [markdown]
# ## Question : drop all a records where we have "NaN values in a "Rows"
#
# ### Pandas DataFrame dropna() Method :
# -Remove all rows wit NULL values from the DataFrame.
# -Sometimes csv file has null values, which are later displayed as NaN in Data Frame. Pandas dropna() method allows the user to analyze and drop Rows/Columns with Null values in different ways.
#  - Syntax :
#    - Signature:
#    - axis: 'Axis' = 0, ----> axis takes int or string value for rows/columns. Input can be rows = 0 or columns = 1 for Integer and ‘index’ or ‘columns’ for String.
#    - how: 'str | NoDefault' = <no_default>,
#    - thresh: 'int | NoDefault' = <no_default>----> thresh: thresh takes integer value which tells minimum amount of na values to drop.
#    - subset: 'IndexLabel' = None,
#    - inplace: 'bool' = False,

# %%
## check Rows :

data1.dropna()
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
#
#                                                        Fare Cabin
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123

# %%
## check Colume : ستونهایی که " ان ای ان " ندارند را جدا می کند 

data1.dropna(axis = 1)
# Out:
#                                                     Pclass     Sex     Fare
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  71.2833
# Heikkinen, Miss. Laina                                   3  female   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  53.1000
# Allen, Mr. William Henry                                 3    male   8.0500
# Moran, Mr. James                                         3    male   8.4583

# %%
## Used thresh: 
## thresh = 1 means one "NaN" value is required in colume 
data1.dropna(axis = 1 , thresh = 1)
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
# Moran, Mr. James                                         3    male   NaN
#
#                                                        Fare Cabin
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Heikkinen, Miss. Laina                               7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123
# Allen, Mr. William Henry                             8.0500   NaN
# Moran, Mr. James                                     8.4583   NaN

# %%
## thresh = 3 means more than there  "NaN" value is required in colume 
data1.dropna(axis = 1 , thresh = 3)
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
# Moran, Mr. James                                         3    male   NaN
#
#                                                        Fare
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833
# Heikkinen, Miss. Laina                               7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000
# Allen, Mr. William Henry                             8.0500
# Moran, Mr. James                                     8.4583

# %%
data1.dropna(axis = 1 , thresh = 5)
# Out:
#                                                     Pclass     Sex     Fare
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  71.2833
# Heikkinen, Miss. Laina                                   3  female   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  53.1000
# Allen, Mr. William Henry                                 3    male   8.0500
# Moran, Mr. James                                         3    male   8.4583

# %%
data1
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
# Moran, Mr. James                                         3    male   NaN
#
#                                                        Fare Cabin
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Heikkinen, Miss. Laina                               7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123
# Allen, Mr. William Henry                             8.0500   NaN
# Moran, Mr. James                                     8.4583   NaN

# %% [markdown]
# ### Python | Pandas DataFrame.fillna() to replace Null values in dataframe :
#
#  - Just like pandas dropna() method manage and remove Null values from a data frame, fillna() manages and let the user replace NaN values with some value of their own.
#
#  -Signature:
# data1.fillna(
# - value: 'Hashable | Mapping | Series | DataFrame' = None,
#     *,
# - method: 'FillnaOptions | None' = None,
# - axis: 'Axis | None' = None,
# - inplace: 'bool' = False,
# - limit: 'int | None' = None,
# - downcast: 'dict | None' = None,

# %%
### Replace "Farshid" insted of "NaN" 

data1.fillna("Farshid")
# Out:
#                                                     Pclass     Sex      Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female     38.0
# Heikkinen, Miss. Laina                                   3  female     26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female     35.0
# Allen, Mr. William Henry                                 3    male     35.0
# Moran, Mr. James                                         3    male  Farshid
#
#                                                        Fare    Cabin
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833      C85
# Heikkinen, Miss. Laina                               7.9250  Farshid
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000     C123
# Allen, Mr. William Henry                             8.0500  Farshid
# Moran, Mr. James                                     8.4583  Farshid

# %%
### Calculate Means of all "Age" and replace to "NaN"

data1.fillna(data1["Age"].mean())
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
# Moran, Mr. James                                         3    male  33.5
#
#                                                        Fare Cabin
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Heikkinen, Miss. Laina                               7.9250  33.5
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123
# Allen, Mr. William Henry                             8.0500  33.5
# Moran, Mr. James                                     8.4583  33.5

# %% [markdown]
# ### Python | Pandas dataframe.groupby() :
#  -Pandas groupby is used for grouping the data according to the categories and apply a function to the categories. It also helps to aggregate data efficiently.
#  -Signature:
# data1.groupby(
# - by=None,
# - axis: 'Axis' = 0,
# - level: 'IndexLabel | None' = None,
# - as_index: 'bool' = True,
# - sort: 'bool' = True,
# - group_keys: 'bool | lib.NoDefault' = <no_default>,
# - squeeze: 'bool | lib.NoDefault' = <no_default>,
# - observed: 'bool' = False,
# - dropna: 'bool' = True,

# %%
data1.groupby("Sex").count()
# Out:
#         Pclass  Age  Fare  Cabin
# Sex
# female       3    3     3      2
# male         2    1     2      0

# %%
data1.groupby("Sex").mean()
# Out:
# /tmp/ipykernel_77/3633039205.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data1.groupby("Sex").mean()
#           Pclass   Age       Fare
# Sex
# female  1.666667  33.0  44.102767
# male    3.000000  35.0   8.254150

# %%
data1.groupby("Sex").sum()
# Out:
# /tmp/ipykernel_77/1095502595.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data1.groupby("Sex").sum()
#         Pclass   Age      Fare
# Sex
# female       5  99.0  132.3083
# male         6  35.0   16.5083

# %%
data1.groupby("Sex").sum()["Fare"]
# Out:
# /tmp/ipykernel_77/3623210938.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data1.groupby("Sex").sum()["Fare"]
# Sex
# female    132.3083
# male       16.5083
# Name: Fare, dtype: float64

# %%
data1.groupby("Sex").mean()["Age"]
# Out:
# /tmp/ipykernel_77/3637869686.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data1.groupby("Sex").mean()["Age"]
# Sex
# female    33.0
# male      35.0
# Name: Age, dtype: float64

# %%
data1
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
# Moran, Mr. James                                         3    male   NaN
#
#                                                        Fare Cabin
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Heikkinen, Miss. Laina                               7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123
# Allen, Mr. William Henry                             8.0500   NaN
# Moran, Mr. James                                     8.4583   NaN

# %%
data2 = data.iloc[0:5 , 0:5]

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %% [markdown]
# ### How To Concatenate Two or More Pandas DataFrames? :
# -A concatenation of two or more data frames can be done using pandas.concat() method. concat() in pandas works by combining Data Frames across rows or columns. We can concat two or more data frames either along rows  (axis=0) or along columns (axis=1)

# %% [markdown]
# ## Question : Try to Merge data :
# -We have data1 and data2 and we want to merge horizontal and vertical.
# - axis: 'Axis' = 0,
# - join: 'str' = 'outer',
# - ignore_index: 'bool' = False,
# - keys=None,
# - levels=None,
# - names=None,
# - verify_integrity: 'bool' = False,
# - sort: 'bool' = False,
# - copy: 'bool' = True,
#
# - https://pandas.pydata.org/docs/reference/api/pandas.concat.html

# %%
##horizontal
pd.concat([data1,data2])
# Out:
#                                                     Pclass     Sex   Age  \
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
# Moran, Mr. James                                         3    male   NaN
# 0                                                        3    male   NaN
# 1                                                        1  female   NaN
# 2                                                        3  female   NaN
# 3                                                        1  female   NaN
# 4                                                        3    male   NaN
#
#                                                        Fare Cabin  \
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# ...

# %% [markdown]
# ## try to change axis :

# %%
## Vertical
pd.concat([data1,data2] , axis = 1)
# Out:
#                                                     Pclass     Sex   Age  \
# Cumings, Mrs. John Bradley (Florence Briggs Tha...     1.0  female  38.0
# Heikkinen, Miss. Laina                                 3.0  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           1.0  female  35.0
# Allen, Mr. William Henry                               3.0    male  35.0
# Moran, Mr. James                                       3.0    male   NaN
# 0                                                      NaN     NaN   NaN
# 1                                                      NaN     NaN   NaN
# 2                                                      NaN     NaN   NaN
# 3                                                      NaN     NaN   NaN
# 4                                                      NaN     NaN   NaN
#
#                                                        Fare Cabin  \
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# ...

# %%
data1
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
# Moran, Mr. James                                         3    male   NaN
#
#                                                        Fare Cabin
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Heikkinen, Miss. Laina                               7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123
# Allen, Mr. William Henry                             8.0500   NaN
# Moran, Mr. James                                     8.4583   NaN

# %% [markdown]
# ## Add own Function to Pandas (External function add to particular column)

# %% [markdown]
# ### Applying Lambda functions to Pandas Dataframe :
# -In Pandas, we have the freedom to add different functions whenever needed like lambda function, sort function, etc. We can apply a lambda function to both the columns and rows of the Pandas data frame.
# -pandas.DataFrame.apply() can be used with python lambda to execute expression. A lambda function in python is a small anonymous function that can take any number of arguments and execute an expression.
# - Syntax :
# - DataFrame.apply(func,
# - axis=0,
# - *raw=False,
# - result_type=None,
# - args=(),
# - **kwargs)
# - https://www.geeksforgeeks.org/applying-lambda-functions-to-pandas-dataframe/
#
# ### .apply(lambda x :  )

# %%
data1["new"] = data1["Pclass"]

# %%
data1
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
# Moran, Mr. James                                         3    male   NaN
#
#                                                        Fare Cabin  new
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85    1
# Heikkinen, Miss. Laina                               7.9250   NaN    3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123    1
# Allen, Mr. William Henry                             8.0500   NaN    3
# Moran, Mr. James                                     8.4583   NaN    3

# %%
### We want to divided Pclass by 3 ??????????? (We used lambda)

data1["new"] = data1["Pclass"].apply(lambda x : x/3)

# %%
data1
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
# Moran, Mr. James                                         3    male   NaN
#
#                                                        Fare Cabin       new
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85  0.333333
# Heikkinen, Miss. Laina                               7.9250   NaN  1.000000
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123  0.333333
# Allen, Mr. William Henry                             8.0500   NaN  1.000000
# Moran, Mr. James                                     8.4583   NaN  1.000000

# %% [markdown]
# ## Add own Function to Pandas (External function add to particular column)

# %%
def fun1(x):
    return x/3

# %%
data1["new"] = data1["Pclass"].apply(fun1)

# %%
data1
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
# Moran, Mr. James                                         3    male   NaN
#
#                                                        Fare Cabin       new
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85  0.333333
# Heikkinen, Miss. Laina                               7.9250   NaN  1.000000
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123  0.333333
# Allen, Mr. William Henry                             8.0500   NaN  1.000000
# Moran, Mr. James                                     8.4583   NaN  1.000000

# %% [markdown]
# ## Create data to store length of "Name"

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
data2["length_name"] = data2["Name"].apply(len)

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  length_name
# 0                            Braund, Mr. Owen Harris    male           23
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female           51
# 2                             Heikkinen, Miss. Laina  female           22
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female           44
# 4                           Allen, Mr. William Henry    male           24

# %% [markdown]
# ##  Create a new column when "PassengerId" lesser than 3 keep a data as it is(No change) , and when greater or equel to 3 try to
# ## find of "logarithm" of data .

# %%
import math
def cust1(x):
    if x < 3:
        return x
    else :
        return math.log10(x)

# %%
data2["PassengerId_Filter"] = data2["PassengerId"].apply(cust1)

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  length_name  \
# 0                            Braund, Mr. Owen Harris    male           23
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female           51
# 2                             Heikkinen, Miss. Laina  female           22
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female           44
# 4                           Allen, Mr. William Henry    male           24
#
#    PassengerId_Filter
# 0            1.000000
# 1            2.000000
# 2            0.477121
# 3            0.602060
# 4            0.698970

# %% [markdown]
# ## Wherever we have a female try to make it as 1 and for male add 0

# %%
def test2(x):
    if x == "female" : 
        return 1
    else:
        return 0

# %%
data2["Sex_test2"] = data2["Sex"].apply(test2)

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  length_name  \
# 0                            Braund, Mr. Owen Harris    male           23
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female           51
# 2                             Heikkinen, Miss. Laina  female           22
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female           44
# 4                           Allen, Mr. William Henry    male           24
#
#    PassengerId_Filter  Sex_test2
# 0            1.000000          0
# 1            2.000000          1
# 2            0.477121          1
# 3            0.602060          1
# 4            0.698970          0

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# ## Average of "Age" in "NaN" value (Pandas DataFrame.fillna() "NaN" values") -
# ### Based on "Fare" separate customers "A" , "B" ,"C" and filtred .

# %% [markdown]
# - 0-100   - "A"
# - 101-199 - "B"
# - 200+    - "C"

# %%
def test3(x):
    if x <= 100 : 
        return "A"
    elif x > 100 and x < 200:
        return "B"
    else :
        return "C"

# %%
data["Fare_Group"] = data["Fare"].apply(test3)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
